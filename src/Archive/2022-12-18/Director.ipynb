# %% [markdown]
# # CMBL

# %% [markdown]
# ## Global variables

# %%
numberOfSamples = 500
#outputDirectory = r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\BatchCurrent\Data_Source\Simulation-Files"
outputDirectory = r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatch\Data_Source\Simulation-Files"
weatherFilePath = r"C:\EnergyPlusV22-2-0\WeatherData\DEU_Munich.108660_IWEC.epw"
requiredUValuesPath = r"C:\Git\Work\FOR2363\Parametric-H-Shape-Office-Building-Model\src\simulation\Required-U-Values.csv"
directorScriptPath = "Director.gh"
reportScriptPath = "Reporting.gh"
simulationScriptPath = "Simulation.gh"
computeUrl = "http://localhost:6500/"

newDesignSpaceMatrix = False

# %% [markdown]
# ## Sampling

# %%
from doepy import build, read_write
from pandas import read_csv

# %%
terrain = {'0':'Ocean','1': 'Country','2':'Suburbs','3':'Urban','4':'City'}
fassade = {'0':'Horizontal-Windows', '1':'Vertical-Windows', '2':'Ribbon-Windows'}
shading = {'0':'External-Shading','1': 'Low-SHGC-Value'}
energyStandard = {'0':'GEG','1': 'NZEB','2':'Passive','3':'70s'}
hvacSystem = {'0':'IdealAirSystem',
'1':'ElectricBaseboard',
'2':'BoilerBaseboard',
'3':'ASHPBaseboard',
'4':'DHWBaseboard',
'5':'EvapCoolers_ElectricBaseboard',
'6':'EvapCoolers_BoilerBaseboard',
'7':'EvapCoolers_ASHPBaseboard',
'8':'EvapCoolers_DHWBaseboard',
'9':'EvapCoolers_Furnace',
'10':'EvapCoolers_UnitHeaters',
'11':'EvapCoolers',
'12':'FCU_Chiller_Boiler',
'13':'FCU_Chiller_ASHP',
'14':'FCU_Chiller_DHW',
'15':'FCU_Chiller_ElectricBaseboard',
'16':'FCU_Chiller_GasHeaters',
'17':'FCU_Chiller',
'18':'FCU_ACChiller_Boiler',
'19':'FCU_ACChiller_ASHP',
'20':'FCU_ACChiller_DHW',
'21':'FCU_ACChiller_ElectricBaseboard',
'22':'FCU_ACChiller_GasHeaters',
'23':'FCU_ACChiller',
'24':'FCU_DCW_Boiler',
'25':'FCU_DCW_ASHP',
'26':'FCU_DCW_DHW',
'27':'FCU_DCW_ElectricBaseboard',
'28':'FCU_DCW_GasHeaters',
'29':'FCU_DCW',
'30':'GasHeaters',
'31':'ResidentialAC_ElectricBaseboard',
'32':'ResidentialAC_BoilerBaseboard',
'33':'ResidentialAC_ASHPBaseboard',
'34':'ResidentialAC_DHWBaseboard',
'35':'ResidentialAC_ResidentialFurnace',
'36':'ResidentialAC',
'37':'ResidentialHP',
'38':'ResidentialHPNoCool',
'39':'ResidentialFurnace',
'40':'VRF',
'41':'WSHP_FluidCooler_Boiler',
'42':'WSHP_CoolingTower_Boiler',
'43':'WSHP_GSHP',
'44':'WSHP_DCW_DHW',
'45':'WindowAC_ElectricBaseboard',
'46':'WindowAC_BoilerBaseboard',
'47':'WindowAC_ASHPBaseboard',
'48':'WindowAC_DHWBaseboard',
'49':'WindowAC_Furnace',
'50':'WindowAC_GasHeaters',
'51':'WindowAC',
'52':'Radiant_Chiller_Boiler',
'53':'Radiant_Chiller_ASHP',
'54':'Radiant_Chiller_DHW',
'55':'Radiant_ACChiller_Boiler',
'56':'Radiant_ACChiller_DHW',
'57':'Radiant_DCW_Boiler',
'58':'Radiant_DCW_ASHP',
'59':'Radiant_DCW_DHW',
'60':'VAV_Chiller_Boiler',
'61':'VAV_Chiller_ASHP',
'62':'VAV_Chiller_DHW',
'63':'VAV_Chiller_PFP',
'64':'VAV_Chiller_GasCoil',
'65':'VAV_ACChiller_Boiler',
'66':'VAV_ACChiller_ASHP',
'67':'VAV_ACChiller_DHW',
'68':'VAV_ACChiller_PFP',
'69':'VAV_ACChiller_GasCoil',
'70':'VAV_DCW_Boiler',
'71':'VAV_DCW_ASHP',
'72':'VAV_DCW_DHW',
'73':'VAV_DCW_PFP',
'74':'VAV_DCW_GasCoil',
'75':'PVAV_Boiler',
'76':'PVAV_ASHP',
'77':'PVAV_DHW',
'78':'PVAV_PFP',
'79':'PVAV_BoilerElectricReheat',
'80':'PSZAC_ElectricBaseboard',
'81':'PSZAC_BoilerBaseboard',
'82':'PSZAC_DHWBaseboard',
'83':'PSZAC_GasHeaters',
'84':'PSZAC_ElectricCoil',
'85':'PSZAC_GasCoil',
'86':'PSZAC_Boiler',
'87':'PSZAC_ASHP',
'88':'PSZAC_DHW',
'89':'PSZAC',
'90':'PSZAC_DCW_ElectricBaseboard',
'91':'PSZAC_DCW_BoilerBaseboard',
'92':'PSZAC_DCW_GasHeaters',
'93':'PSZAC_DCW_ElectricCoil',
'94':'PSZAC_DCW_GasCoil',
'95':'PSZAC_DCW_Boiler',
'96':'PSZAC_DCW_ASHP',
'97':'PSZAC_DCW_DHW',
'98':'PSZAC_DCW',
'99':'PSZHP',
'100':'PTAC_ElectricBaseboard',
'101':'PTAC_BoilerBaseboard',
'102':'PTAC_DHWBaseboard',
'103':'PTAC_GasHeaters',
'104':'PTAC_ElectricCoil',
'105':'PTAC_GasCoil',
'106':'PTAC_Boiler',
'107':'PTAC_ASHP',
'108':'PTAC_DHW',
'109':'PTAC',
'110':'PTHP',
'111':'Furnace',
'112':'DOAS_FCU_Chiller_Boiler',
'113':'DOAS_FCU_Chiller_ASHP',
'114':'DOAS_FCU_Chiller_DHW',
'115':'DOAS_FCU_Chiller_ElectricBaseboard',
'116':'DOAS_FCU_Chiller_GasHeaters',
'117':'DOAS_FCU_Chiller',
'118':'DOAS_FCU_ACChiller_Boiler',
'119':'DOAS_FCU_ACChiller_ASHP',
'120':'DOAS_FCU_ACChiller_DHW',
'121':'DOAS_FCU_ACChiller_ElectricBaseboard',
'122':'DOAS_FCU_ACChiller_GasHeaters',
'123':'DOAS_FCU_ACChiller',
'124':'DOAS_FCU_DCW_Boiler',
'125':'DOAS_FCU_DCW_ASHP',
'126':'DOAS_FCU_DCW_DHW',
'127':'DOAS_FCU_DCW_ElectricBaseboard',
'128':'DOAS_FCU_DCW_GasHeaters',
'129':'DOAS_FCU_DCW',
'130':'DOAS_VRF',
'131':'DOAS_WSHP_FluidCooler_Boiler',
'132':'DOAS_WSHP_CoolingTower_Boiler',
'133':'DOAS_WSHP_GSHP',
'134':'DOAS_WSHP_DCW_DHW',
'135':'DOAS_Radiant_Chiller_Boiler',
'136':'DOAS_Radiant_Chiller_ASHP',
'137':'DOAS_Radiant_Chiller_DHW',
'138':'DOAS_Radiant_ACChiller_Boiler',
'139':'DOAS_Radiant_ACChiller_DHW',
'140':'DOAS_Radiant_DCW_Boiler',
'141':'DOAS_Radiant_DCW_ASHP',
'142':'DOAS_Radiant_DCW_DHW',
}
serviceHotWater = {'0':'Gas_WaterHeater',
'1':'Electric_WaterHeater',
'2':'HeatPump_WaterHeater',
'3':'Gas_TanklessHeater',
'4':'Electric_TanklessHeater',}
buildingSystemVintage = {'0':'2019',
'1':'2016',
'2':'2013',
'3':'2010',
'4':'2007',
'5':'2004',
'6':'1980_2004',
'7':'pre_1980',}

# %%
if newDesignSpaceMatrix:
    data_in=read_write.read_variables_csv('Parameters.csv')
    designSpaceMatrix = build.space_filling_lhs(data_in,num_samples = numberOfSamples)
    designSpaceMatrix = designSpaceMatrix.round(2)

    integerColumnNames = ['Orientation','NumberOfFloors', 'Arm-Latitudinal-NumberOfSegments',
    'Arm-Longitudinal-NumberOfSegments','BaseBody-Inside-Latditudinal-NumberOfSegments']
    boolIntegerColumnNames = ['Has_Courtyard-Roof']
    textColumnNames = ['Terrain','Fassade','Shading','EnergyStandard','HVAC-System','ServiceHotWater','BuildingSystemVintage',]

    roundDict = {}
    for nonNumberColumnName in integerColumnNames + boolIntegerColumnNames + textColumnNames:
        roundDict[nonNumberColumnName]=0
    designSpaceMatrix = designSpaceMatrix.round(roundDict)

    for integerColumnName in integerColumnNames:
        designSpaceMatrix[integerColumnName]=designSpaceMatrix[integerColumnName].astype('int')

    for boolIntegerColumnName in boolIntegerColumnNames:
        designSpaceMatrix[boolIntegerColumnName]=designSpaceMatrix[boolIntegerColumnName].astype('bool')

    for textColumnName in textColumnNames:
        designSpaceMatrix[textColumnName]=designSpaceMatrix[textColumnName].astype('int')
        designSpaceMatrix[textColumnName]=designSpaceMatrix[textColumnName].astype('str')

    designSpaceMatrix['Terrain'] = designSpaceMatrix['Terrain'].map(terrain)
    designSpaceMatrix['Fassade'] = designSpaceMatrix['Fassade'].map(fassade)
    designSpaceMatrix['Shading'] = designSpaceMatrix['Shading'].map(shading)
    designSpaceMatrix['EnergyStandard'] = designSpaceMatrix['EnergyStandard'].map(energyStandard)
    designSpaceMatrix['HVAC-System'] = designSpaceMatrix['HVAC-System'].map(hvacSystem)
    designSpaceMatrix['ServiceHotWater'] = designSpaceMatrix['ServiceHotWater'].map(serviceHotWater)
    designSpaceMatrix['BuildingSystemVintage'] = designSpaceMatrix['BuildingSystemVintage'].map(buildingSystemVintage)

    designSpaceMatrix.to_csv('DesignSpaceMatrix.csv')
    print(designSpaceMatrix.dtypes)
else:
    designSpaceMatrix = read_csv('DesignSpaceMatrix.csv')
designSpaceMatrix
# Out:
#      Unnamed: 0  Terrain  Orientation  NumberOfFloors  FloorHeight  \
# 0             0    Urban           60               7         3.74
# 1             1    Urban          106               8         4.26
# 2             2     City           40               1         3.31
# 3             3     City           75               4         3.61
# 4             4  Country           89               5         3.70
# ..          ...      ...          ...             ...          ...
# 495         495  Suburbs          143               6         3.91
# 496         496  Suburbs          118               5         4.01
# 497         497    Urban           13               6         2.96
# 498         498    Urban           23              10         3.41
# 499         499    Urban           79               2         2.85
#
#                 Fassade  RasterLength-X  RasterLength-Y  \
# 0      Vertical-Windows            2.53            2.51
# 1      Vertical-Windows            3.19            3.86
# 2      Vertical-Windows            2.88            2.16
# 3      Vertical-Windows            2.65            3.42
# 4        Ribbon-Windows            2.76            3.68
# ..                  ...             ...             ...
# 495  Horizontal-Windows            2.87            3.84
# 496    Vertical-Windows            2.50            2.18
# 497  Horizontal-Windows            2.81            3.03
# 498      Ribbon-Windows            2.96            2.06
# 499  Horizontal-Windows            2.29            2.95
#
#      Arm-Latitudinal-NumberOfSegments  Arm-Longitudinal-NumberOfSegments  \
# 0                                   4                                  3
# 1                                   4                                  3
# 2                                   4                                  4
# 3                                   5                                  5
# 4                                   4                                  4
# ..                                ...                                ...
# 495                                 5                                  3
# 496                                 4                                  5
# 497                                 4                                  5
# 498                                 4                                  3
# 499                                 4                                  3
#
#      BaseBody-Inside-Latditudinal-NumberOfSegments  \
# 0                                                4
# 1                                                4
# 2                                                4
# 3                                                2
# 4                                                3
# ..                                             ...
# 495                                              4
# 496                                              2
# 497                                              3
# 498                                              3
# 499                                              4
#
#      Courtyard_SegmentCount_RasterLength-Y  Has_Courtyard-Roof  \
# 0                                    11.95               False
# 1                                     8.47               False
# 2                                     8.19               False
# 3                                    10.85                True
# 4                                    11.97                True
# ..                                     ...                 ...
# 495                                  11.27                True
# 496                                   8.33                True
# 497                                  12.60                True
# 498                                   9.74               False
# 499                                   9.30               False
#
#               Shading EnergyStandard      HVAC-System  \
# 0      Low-SHGC-Value            GEG     DHWBaseboard
# 1    External-Shading           NZEB    ASHPBaseboard
# 2      Low-SHGC-Value        Passive     DHWBaseboard
# 3    External-Shading        Passive  BoilerBaseboard
# 4    External-Shading        Passive     DHWBaseboard
# ..                ...            ...              ...
# 495  External-Shading        Passive  BoilerBaseboard
# 496  External-Shading           NZEB     DHWBaseboard
# 497  External-Shading            GEG  BoilerBaseboard
# 498    Low-SHGC-Value           NZEB  BoilerBaseboard
# 499  External-Shading           NZEB    ASHPBaseboard
#
#              ServiceHotWater BuildingVintage
# 0         Gas_TanklessHeater        pre_1980
# 1       HeatPump_WaterHeater            2007
# 2            Gas_WaterHeater            2016
# 3            Gas_WaterHeater            2010
# 4         Gas_TanklessHeater       1980_2004
# ..                       ...             ...
# 495       Gas_TanklessHeater            2019
# 496  Electric_TanklessHeater            2016
# 497     HeatPump_WaterHeater            2010
# 498       Gas_TanklessHeater            2016
# 499     HeatPump_WaterHeater            2010
#
# [500 rows x 18 columns]

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Definitions

# %%
import compute_rhino3d
import compute_rhino3d.Grasshopper as gh
from rhino3dm import GeometryBase,File3dm,CommonObject,ObjectAttributes,Point3d
import json
from numpy import float64, int32, bool_

# %%
compute_rhino3d.Util.authToken = ""
compute_rhino3d.Util.url = computeUrl

# %%
def callGrasshopper(path,parameters):
    trees = convertToTrees(parameters)
    return gh.EvaluateDefinition(path, trees)

def convertToTrees(parameters):
    trees = []
    if type(parameters) is not dict:
        return "Parameters have to be a dictionary"
    for kw in parameters:
        branches = parameters[kw]
        tree = gh.DataTree(kw)
        #check if branches is just item
        if type(branches) != list:
            tree.Append([0], [encode(branches)])
        else:
            #check if branches is list
            if type(branches[0]) != list:
                tree.Append([0], [encode(item) for item in branches])
            else:
                for i,branch in enumerate(branches):
                    tree.Append([i], [encode(item) for item in branch])
        trees.append(tree)
    return trees

def encode(value):
    if type(value).__module__.startswith('rhino3dm'):
        return json.dumps(value.Encode())
    else:
        return value

# %% [markdown]
# ## Post processing of results

# %% [markdown]
# ### Definitions

# %%
import csv
from os.path import exists

# %%
def parseSingleResults(valuesReply):
    results = {}
    log = []
    for valueReply in valuesReply['values']:
        tree = valueReply['InnerTree']
        if len(tree)!=1:
            log.append("Tree did not have exactly one 1 branch" +valueReply)
            continue
        value =list(tree.values())[0]
        if len(value)!=1:
            log.append("Branch did not have exactly one 1 value")
        results[valueReply['ParamName']]=value[0]['data'].strip('"')
    return (results,log)

def appendValuesToFile(filePath,fieldnames,values):
    if not exists(filePath):
        with open(filePath, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
    with open(filePath, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writerow(values)

# %% [markdown]
# ### Write

# %%
# cleanResults,log = parseSingleResults(reportResult)
# values = {**parameters,**cleanResults}
# appendValuesToFile("results.csv",list(parameters.keys())+list(cleanResults.keys()),values)
# values

# %% [markdown]
# ## Batch

# %%
from os.path import join
from os import rename,getcwd

# %%
modelNames = []
energyPlusGroupPath = join(outputDirectory,"group.epg")

"""Compute wrapps a path and returns the literal wrapping. 
Therefore all wrappable characters must be mapped to normal ones."""
def encryptPathForCompute(path):
    return path.replace('\\','%').replace(':','$')

def getModelName(i):
    return "Simulation"+str(i).zfill(3)

def translateToHoneybee(i):
    modelName = getModelName(i)
    print(f"{modelName} starting.")
    parameters = designSpaceMatrix.iloc[i].to_dict()
    parameters ['ModelName']=modelName
    #parameters['Scripts-Directory'] = encryptPathForCompute(getcwd())
    #parameters['Required-U-Values-Path'] = encryptPathForCompute(requiredUValuesPath)
    # parameters['EPW-FilePath'] = encryptPathForCompute(weatherFilePath)
    parameters['Output-Directory'] = encryptPathForCompute(outputDirectory)

    modelDirectory = join(outputDirectory,modelName)

    print(parameters)
    try:
        appendValuesToFile(join(modelDirectory,"parameters.csv"),list(parameters.keys()),parameters)
    except:
        pass
    r = callGrasshopper(directorScriptPath,parameters)
    print(f"{modelName} finished.")
    return r

def translateToIdf(i,simulate=False):
    modelName = getModelName(i)
    designParameters = designSpaceMatrix.iloc[i].to_dict()

    parameters = {
        'Terrain': designParameters['Terrain'],
        'Honeybee-FilePath': encryptPathForCompute(join(outputDirectory, modelName + ".hbjson")),
        'EPW-FilePath': encryptPathForCompute(weatherFilePath),
        'Output-Directory': encryptPathForCompute(outputDirectory),
        'Output-Names':[],
        'Report-Names':["AllSummary"],
        'SimulationMode':"1" if simulate else "0",
        'AdditionalIDF':"!-Dummy"
    }

    if designParameters['HVAC-System'] == 'ASHPBaseboard':
        parameters['AdditionalIDF']+="""\nEnergyManagementSystem:OutputVariable,
  Central Air Source Heat Pump Capacity, ! Name
  Cap, ! EMS Variable Name
  Averaged, ! Type of Data in Variable
  SystemTimestep, ! Update Frequency
  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name
  W;"""
        parameters['Output-Names'].append("Central Air Source Heat Pump Capacity")
    if "Baseboard" in designParameters['HVAC-System']:
        parameters['Output-Names'].append("Baseboard Total Heating Rate")
        parameters['Output-Names'].append("Baseboard Total Heating Energy")
        parameters['Output-Names'].append("Baseboard Hot Water Energy")
        parameters['Output-Names'].append("Baseboard Hot Water Mass Flow Rate")
        parameters['Output-Names'].append("Baseboard Air Inlet Temperature")
        parameters['Output-Names'].append("Baseboard Air Outlet Temperature")
        parameters['Output-Names'].append("Baseboard Water Inlet Temperature")
        parameters['Output-Names'].append("Baseboard Water Outlet Temperature")
    if "Boiler" in designParameters['HVAC-System']:
        parameters['Output-Names'].append("Boiler Heating Rate")
        parameters['Output-Names'].append("Boiler Heating Energy")
        parameters['Output-Names'].append("Boiler Inlet Temperature")
        parameters['Output-Names'].append("Boiler Outlet Temperature")
        parameters['Output-Names'].append("Boiler Mass Flow Rate")
        parameters['Output-Names'].append("Boiler Parasitic Electricity Rate")
        parameters['Output-Names'].append("Boiler Ancillary Electricity Energy")
        parameters['Output-Names'].append("Boiler Part Load Ratio")
        parameters['Output-Names'].append("Boiler Efficiency")
        parameters['Output-Names'].append("Boiler Gas Rate")
        parameters['Output-Names'].append("Boiler Gas Energy")
    if "DHW" in designParameters['HVAC-System']:
        parameters['Output-Names'].append("District Heating Rate")
        parameters['Output-Names'].append("District Heating Hot Water Rate")
        parameters['Output-Names'].append("District Heating Hot Water Energy")
        parameters['Output-Names'].append("District Heating Inlet Temperature")
        parameters['Output-Names'].append("District Heating Outlet Temperature")
        parameters['Output-Names'].append("District Heating Mass Flow Rate")

    parameters['Output-Names'].append("Water Heater Tank Temperature")
    parameters['Output-Names'].append("Water Heater Heat Loss Rate")
    parameters['Output-Names'].append("Water Heater Heat Loss Energy")
    parameters['Output-Names'].append("Water Heater Use Side Mass Flow Rate")
    parameters['Output-Names'].append("Water Heater Use Side Inlet Temperature")
    parameters['Output-Names'].append("Water Heater Use Side Outlet Temperature")
    parameters['Output-Names'].append("Water Heater Use Side Heat Transfer Rate")
    parameters['Output-Names'].append("Water Heater Use Side Heat Transfer Energy")
    parameters['Output-Names'].append("Water Heater Source Side Mass Flow Rate")
    parameters['Output-Names'].append("Water Heater Source Side Inlet Temperature")
    parameters['Output-Names'].append("Water Heater Source Side Outlet Temperature")
    parameters['Output-Names'].append("Water Heater Source Side Heat Transfer Rate")
    parameters['Output-Names'].append("Water Heater Source Side Heat Transfer Energy")
    parameters['Output-Names'].append("Water Heater Total Demand Heat Transfer Rate")
    parameters['Output-Names'].append("Water Heater Total Demand Energy")
    parameters['Output-Names'].append("Water Heater Heating Rate")
    parameters['Output-Names'].append("Water Heater Electricity Rate")
    parameters['Output-Names'].append("Water Heater Gas Rate")
        
    r =callGrasshopper(simulationScriptPath,parameters)

    modelDirectory = join(outputDirectory,modelName)
    runDirectory =  join(modelDirectory,"openstudio","run")
    f = open(energyPlusGroupPath, "a")
    f.write(join(runDirectory,"in.idf") + "," + weatherFilePath + "," + join(runDirectory,"eplusout") + ",1\n")
    f.close()
    print(parameters)
    try:
        appendValuesToFile(join(modelDirectory,"parameters.csv"),list(parameters.keys()),parameters)
    except:
        pass
    print(f"{modelName} finished.")

    return r 

def renameOutputs(i):
    modelName = "Simulation"+str(i).zfill(3)
    modelDirectory = join(outputDirectory,modelName)
    runDirectory =  join(modelDirectory,"openstudio","run")
    try:
        name = 'eplusout'
        rename(join(runDirectory, name+'Table.html'), join(runDirectory,'eplustbl.htm'))
        rename(join(runDirectory,name +'.sql'), join(runDirectory,'eplusout.sql'))
    except:
        pass

def gather(i):
    try:
        parameters = designSpaceMatrix.iloc[i].to_dict()
        modelName = "Simulation"+str(i).zfill(3)
        print(f"{modelName} starting.")
        reportResult = callGrasshopper(reportScriptPath,
        {'ModelName':modelName,'Output-Directory':encryptPathForCompute(outputDirectory)})
        cleanResults,log = parseSingleResults(reportResult)
        values = {'Simulation':modelName,**cleanResults}
        appendValuesToFile(join(outputDirectory,"results.csv"),
            ["Simulation"]+list(cleanResults.keys()),values)
        print(f"{modelName} writing.")
    except:
        pass

# %%
# s=0
# translateToHoneybee(s)
# translateToIdf(s,True)
# renameOutputs(s)
# gather(s)

# %%
# for i in range(len(designSpaceMatrix)):
#     try:
#         translateToHoneybee(i)
#         translateToIdf(i)
#     except:
#         pass
# Out:
# Simulation000 starting.
# {'Unnamed: 0': 0, 'Terrain': 'Urban', 'Orientation': 60, 'NumberOfFloors': 7, 'FloorHeight': 3.74, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.53, 'RasterLength-Y': 2.51, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 11.95, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'GEG', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': 'pre_1980', 'ModelName': 'Simulation000', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation000 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation000.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation000 finished.
# Simulation001 starting.
# {'Unnamed: 0': 1, 'Terrain': 'Urban', 'Orientation': 106, 'NumberOfFloors': 8, 'FloorHeight': 4.26, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 3.19, 'RasterLength-Y': 3.86, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 8.47, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2007', 'ModelName': 'Simulation001', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation001 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation001.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation001 finished.
# Simulation002 starting.
# {'Unnamed: 0': 2, 'Terrain': 'City', 'Orientation': 40, 'NumberOfFloors': 1, 'FloorHeight': 3.31, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.88, 'RasterLength-Y': 2.16, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 8.19, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'Passive', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Gas_WaterHeater', 'BuildingVintage': '2016', 'ModelName': 'Simulation002', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation002 finished.
# {'Terrain': 'City', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation002.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation002 finished.
# Simulation003 starting.
# {'Unnamed: 0': 3, 'Terrain': 'City', 'Orientation': 75, 'NumberOfFloors': 4, 'FloorHeight': 3.61, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.65, 'RasterLength-Y': 3.42, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 10.85, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Gas_WaterHeater', 'BuildingVintage': '2010', 'ModelName': 'Simulation003', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation003 finished.
# {'Terrain': 'City', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation003.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation003 finished.
# Simulation004 starting.
# {'Unnamed: 0': 4, 'Terrain': 'Country', 'Orientation': 89, 'NumberOfFloors': 5, 'FloorHeight': 3.7, 'Fassade': 'Ribbon-Windows', 'RasterLength-X': 2.76, 'RasterLength-Y': 3.68, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 11.97, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': '1980_2004', 'ModelName': 'Simulation004', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation004 finished.
# {'Terrain': 'Country', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation004.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation004 finished.
# Simulation005 starting.
# {'Unnamed: 0': 5, 'Terrain': 'Suburbs', 'Orientation': 66, 'NumberOfFloors': 7, 'FloorHeight': 3.07, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.16, 'RasterLength-Y': 3.31, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 7.16, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'GEG', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': '2019', 'ModelName': 'Simulation005', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation005 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation005.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation005 finished.
# Simulation006 starting.
# {'Unnamed: 0': 6, 'Terrain': 'City', 'Orientation': 176, 'NumberOfFloors': 8, 'FloorHeight': 3.95, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 3.84, 'RasterLength-Y': 3.95, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 11.0, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': '2004', 'ModelName': 'Simulation006', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation006 finished.
# {'Terrain': 'City', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation006.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation006 finished.
# Simulation007 starting.
# {'Unnamed: 0': 7, 'Terrain': 'Suburbs', 'Orientation': 151, 'NumberOfFloors': 7, 'FloorHeight': 3.06, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 3.65, 'RasterLength-Y': 2.38, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 10.1, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'NZEB', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '2016', 'ModelName': 'Simulation007', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation007 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation007.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation007 finished.
# Simulation008 starting.
# {'Unnamed: 0': 8, 'Terrain': 'Country', 'Orientation': 146, 'NumberOfFloors': 8, 'FloorHeight': 3.61, 'Fassade': 'Ribbon-Windows', 'RasterLength-X': 3.45, 'RasterLength-Y': 2.68, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 11.24, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'GEG', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': 'pre_1980', 'ModelName': 'Simulation008', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation008 finished.
# {'Terrain': 'Country', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation008.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation008 finished.
# Simulation009 starting.
# {'Unnamed: 0': 9, 'Terrain': 'Suburbs', 'Orientation': 60, 'NumberOfFloors': 2, 'FloorHeight': 3.53, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.4, 'RasterLength-Y': 3.08, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 12.83, 'Has_Courtyard-Roof': True, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'Passive', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '1980_2004', 'ModelName': 'Simulation009', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation009 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation009.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation009 finished.
# Simulation010 starting.
# {'Unnamed: 0': 10, 'Terrain': 'Urban', 'Orientation': 57, 'NumberOfFloors': 6, 'FloorHeight': 4.41, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.91, 'RasterLength-Y': 2.96, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 8.77, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2007', 'ModelName': 'Simulation010', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation010 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation010.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation010 finished.
# Simulation011 starting.
# {'Unnamed: 0': 11, 'Terrain': 'Urban', 'Orientation': 12, 'NumberOfFloors': 5, 'FloorHeight': 4.24, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.14, 'RasterLength-Y': 3.03, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 12.33, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '1980_2004', 'ModelName': 'Simulation011', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation011 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation011.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation011 finished.
# Simulation012 starting.
# {'Unnamed: 0': 12, 'Terrain': 'Country', 'Orientation': 52, 'NumberOfFloors': 7, 'FloorHeight': 3.06, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.38, 'RasterLength-Y': 3.42, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 10.61, 'Has_Courtyard-Roof': True, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'GEG', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '2013', 'ModelName': 'Simulation012', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation012 finished.
# {'Terrain': 'Country', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation012.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation012 finished.
# Simulation013 starting.
# {'Unnamed: 0': 13, 'Terrain': 'City', 'Orientation': 9, 'NumberOfFloors': 2, 'FloorHeight': 3.29, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.12, 'RasterLength-Y': 2.52, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 13.0, 'Has_Courtyard-Roof': True, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'NZEB', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2004', 'ModelName': 'Simulation013', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation013 finished.
# {'Terrain': 'City', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation013.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation013 finished.
# Simulation014 starting.
# {'Unnamed: 0': 14, 'Terrain': 'Urban', 'Orientation': 58, 'NumberOfFloors': 10, 'FloorHeight': 3.71, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 3.72, 'RasterLength-Y': 3.4, 'Arm-Latitudinal-NumberOfSegments': 3, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 11.89, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '2007', 'ModelName': 'Simulation014', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation014 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation014.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation014 finished.
# Simulation015 starting.
# {'Unnamed: 0': 15, 'Terrain': 'Urban', 'Orientation': 105, 'NumberOfFloors': 6, 'FloorHeight': 3.84, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.39, 'RasterLength-Y': 3.06, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 11.81, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': 'pre_1980', 'ModelName': 'Simulation015', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation015 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation015.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation015 finished.
# Simulation016 starting.
# {'Unnamed: 0': 16, 'Terrain': 'Urban', 'Orientation': 150, 'NumberOfFloors': 5, 'FloorHeight': 3.35, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.21, 'RasterLength-Y': 3.21, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 9.45, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'Passive', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '2013', 'ModelName': 'Simulation016', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation016 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation016.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation016 finished.
# Simulation017 starting.
# {'Unnamed: 0': 17, 'Terrain': 'Urban', 'Orientation': 63, 'NumberOfFloors': 8, 'FloorHeight': 3.0, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.52, 'RasterLength-Y': 2.52, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 4, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 11.94, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '1980_2004', 'ModelName': 'Simulation017', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation017 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation017.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation017 finished.
# Simulation018 starting.
# {'Unnamed: 0': 18, 'Terrain': 'Suburbs', 'Orientation': 166, 'NumberOfFloors': 6, 'FloorHeight': 3.36, 'Fassade': 'Ribbon-Windows', 'RasterLength-X': 2.32, 'RasterLength-Y': 3.94, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 12.01, 'Has_Courtyard-Roof': True, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'NZEB', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'Electric_WaterHeater', 'BuildingVintage': '2010', 'ModelName': 'Simulation018', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation018 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation018.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation018 finished.
# Simulation019 starting.
# {'Unnamed: 0': 19, 'Terrain': 'Country', 'Orientation': 50, 'NumberOfFloors': 9, 'FloorHeight': 2.85, 'Fassade': 'Ribbon-Windows', 'RasterLength-X': 4.0, 'RasterLength-Y': 3.46, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 8.42, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'GEG', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Electric_TanklessHeater', 'BuildingVintage': '2007', 'ModelName': 'Simulation019', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation019 finished.
# ...
# Simulation493 finished.
# Simulation494 starting.
# {'Unnamed: 0': 494, 'Terrain': 'City', 'Orientation': 27, 'NumberOfFloors': 3, 'FloorHeight': 3.83, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 3.24, 'RasterLength-Y': 3.69, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 7.32, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2013', 'ModelName': 'Simulation494', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation494 finished.
# {'Terrain': 'City', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation494.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation494 finished.
# Simulation495 starting.
# {'Unnamed: 0': 495, 'Terrain': 'Suburbs', 'Orientation': 143, 'NumberOfFloors': 6, 'FloorHeight': 3.91, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.87, 'RasterLength-Y': 3.84, 'Arm-Latitudinal-NumberOfSegments': 5, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 11.27, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'Passive', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': '2019', 'ModelName': 'Simulation495', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation495 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation495.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation495 finished.
# Simulation496 starting.
# {'Unnamed: 0': 496, 'Terrain': 'Suburbs', 'Orientation': 118, 'NumberOfFloors': 5, 'FloorHeight': 4.01, 'Fassade': 'Vertical-Windows', 'RasterLength-X': 2.5, 'RasterLength-Y': 2.18, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 2, 'Courtyard_SegmentCount_RasterLength-Y': 8.33, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'DHWBaseboard', 'ServiceHotWater': 'Electric_TanklessHeater', 'BuildingVintage': '2016', 'ModelName': 'Simulation496', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation496 finished.
# {'Terrain': 'Suburbs', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation496.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'District Heating Rate', 'District Heating Hot Water Rate', 'District Heating Hot Water Energy', 'District Heating Inlet Temperature', 'District Heating Outlet Temperature', 'District Heating Mass Flow Rate', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation496 finished.
# Simulation497 starting.
# {'Unnamed: 0': 497, 'Terrain': 'Urban', 'Orientation': 13, 'NumberOfFloors': 6, 'FloorHeight': 2.96, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.81, 'RasterLength-Y': 3.03, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 5, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 12.6, 'Has_Courtyard-Roof': True, 'Shading': 'External-Shading', 'EnergyStandard': 'GEG', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2010', 'ModelName': 'Simulation497', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation497 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation497.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation497 finished.
# Simulation498 starting.
# {'Unnamed: 0': 498, 'Terrain': 'Urban', 'Orientation': 23, 'NumberOfFloors': 10, 'FloorHeight': 3.41, 'Fassade': 'Ribbon-Windows', 'RasterLength-X': 2.96, 'RasterLength-Y': 2.06, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 3, 'Courtyard_SegmentCount_RasterLength-Y': 9.74, 'Has_Courtyard-Roof': False, 'Shading': 'Low-SHGC-Value', 'EnergyStandard': 'NZEB', 'HVAC-System': 'BoilerBaseboard', 'ServiceHotWater': 'Gas_TanklessHeater', 'BuildingVintage': '2016', 'ModelName': 'Simulation498', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation498 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation498.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Boiler Heating Rate', 'Boiler Heating Energy', 'Boiler Inlet Temperature', 'Boiler Outlet Temperature', 'Boiler Mass Flow Rate', 'Boiler Parasitic Electricity Rate', 'Boiler Ancillary Electricity Energy', 'Boiler Part Load Ratio', 'Boiler Efficiency', 'Boiler Gas Rate', 'Boiler Gas Energy', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy'}
# Simulation498 finished.
# Simulation499 starting.
# {'Unnamed: 0': 499, 'Terrain': 'Urban', 'Orientation': 79, 'NumberOfFloors': 2, 'FloorHeight': 2.85, 'Fassade': 'Horizontal-Windows', 'RasterLength-X': 2.29, 'RasterLength-Y': 2.95, 'Arm-Latitudinal-NumberOfSegments': 4, 'Arm-Longitudinal-NumberOfSegments': 3, 'BaseBody-Inside-Latditudinal-NumberOfSegments': 4, 'Courtyard_SegmentCount_RasterLength-Y': 9.3, 'Has_Courtyard-Roof': False, 'Shading': 'External-Shading', 'EnergyStandard': 'NZEB', 'HVAC-System': 'ASHPBaseboard', 'ServiceHotWater': 'HeatPump_WaterHeater', 'BuildingVintage': '2010', 'ModelName': 'Simulation499', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files'}
# Simulation499 finished.
# {'Terrain': 'Urban', 'Honeybee-FilePath': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files%Simulation499.hbjson', 'EPW-FilePath': 'C$%EnergyPlusV22-2-0%WeatherData%DEU_Munich.108660_IWEC.epw', 'Output-Directory': 'E$%Nextcloud%Public%FOR2363%TP4%LUH%HVAC-Systems%CurrentBatch%Data_Source%Simulation-Files', 'Output-Names': ['Central Air Source Heat Pump Capacity', 'Baseboard Total Heating Rate', 'Baseboard Total Heating Energy', 'Baseboard Hot Water Energy', 'Baseboard Hot Water Mass Flow Rate', 'Baseboard Air Inlet Temperature', 'Baseboard Air Outlet Temperature', 'Baseboard Water Inlet Temperature', 'Baseboard Water Outlet Temperature', 'Water Heater Tank Temperature', 'Water Heater Heat Loss Rate', 'Water Heater Heat Loss Energy', 'Water Heater Use Side Mass Flow Rate', 'Water Heater Use Side Inlet Temperature', 'Water Heater Use Side Outlet Temperature', 'Water Heater Use Side Heat Transfer Rate', 'Water Heater Use Side Heat Transfer Energy', 'Water Heater Source Side Mass Flow Rate', 'Water Heater Source Side Inlet Temperature', 'Water Heater Source Side Outlet Temperature', 'Water Heater Source Side Heat Transfer Rate', 'Water Heater Source Side Heat Transfer Energy', 'Water Heater Total Demand Heat Transfer Rate', 'Water Heater Total Demand Energy', 'Water Heater Heating Rate', 'Water Heater Electricity Rate', 'Water Heater Gas Rate'], 'Report-Names': ['AllSummary'], 'SimulationMode': '0', 'AdditionalIDF': '!-Dummy\nEnergyManagementSystem:OutputVariable,\n  Central Air Source Heat Pump Capacity, ! Name\n  Cap, ! EMS Variable Name\n  Averaged, ! Type of Data in Variable\n  SystemTimestep, ! Update Frequency\n  Hot_Water_Loop_Central_Air_Source_Heat_Pump_Init_Pgrm,           ! EMS Program or Subroutine Name\n  W;'}
# Simulation499 finished.

# %%
# for i in range(10):
#     try:
#         renameOutputs(i)
#         gather(i)
#     except:
#         pass

# %%
# from os.path import exists

# failedSimulations = []

# import csv
# with open(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Training\DesignSpaceMatrix.csv", 'r') as inp, open(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Training\DesignSpaceMatrix_culled.csv", 'w') as out:
#     writer = csv.writer(out)
#     i=0
#     for row in csv.reader(inp):
#         try:
#             modelName = getModelName(i-1)
#             if exists(join(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Source\Simulation-Files",modelName)):
#                 writer.writerow(row)
#         except:
#             pass
#         i+=1
#     inp.close()
#     out.close()

# %%
# import pandas as pd
# #df = pd.read_csv(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Training\DesignSpaceMatrix.csv", 'r')
# #df_s = pd.DataFrame(df)
# with open(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Training\DesignSpaceMatrix.csv", 'r') as inp:
#     writer = csv.writer(out)
#     i=1
#     for row in csv.reader(inp):
#         try:
#             print (row)
#             modelName = getModelName(i)
#             if not exists(join(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Source\Simulation-Files",modelName)):
#                 df_s = df_s.drop(df_s.index[i])
#                 print (modelName)
#         except:
#             pass
#         i+=1
#     inp.close()
# df_s.to_csv(r"E:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\FirstCurrent\Data_Training\DesignSpaceMatrix_culled.csv", index=False, encoding='utf-8')
