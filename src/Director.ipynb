# %% [markdown]
# # CMBL

# %% [markdown]
# ## Sampling

# %%
from doepy import build, read_write

# %%
terrain = {'0':'Ocean','1': 'Country','2':'Suburbs','3':'Urban','4':'City'}
fassade = {'0':'Horizontal-Windows', '1':'Vertical-Windows', '2':'Ribbon-Windows'}
shading = {'0':'External-Shading','1': 'Low-SHGC-Value'}
energyStandard = {'0':'GEG','1': 'NZEB','2':'Passive'}
hvacSystemTemplates = {
'0':'IdealAirSystem',
'1':'ElectricBaseboard',
'2':'BoilerBaseboard',
'3':'ASHPBaseboard',
'4':'DHWBaseboard',
'5':'EvapCoolers_ElectricBaseboard',
'6':'EvapCoolers_BoilerBaseboard',
'7':'EvapCoolers_ASHPBaseboard',
'8':'EvapCoolers_DHWBaseboard',
'9':'EvapCoolers_Furnace',
'10':'EvapCoolers_UnitHeaters',
'11':'EvapCoolers',
'12':'FCU_Chiller_Boiler',
'13':'FCU_Chiller_ASHP',
'14':'FCU_Chiller_DHW',
'15':'FCU_Chiller_ElectricBaseboard',
'16':'FCU_Chiller_GasHeaters',
'17':'FCU_Chiller',
'18':'FCU_ACChiller_Boiler',
'19':'FCU_ACChiller_ASHP',
'20':'FCU_ACChiller_DHW',
'21':'FCU_ACChiller_ElectricBaseboard',
'22':'FCU_ACChiller_GasHeaters',
'23':'FCU_ACChiller',
'24':'FCU_DCW_Boiler',
'25':'FCU_DCW_ASHP',
'26':'FCU_DCW_DHW',
'27':'FCU_DCW_ElectricBaseboard',
'28':'FCU_DCW_GasHeaters',
'29':'FCU_DCW',
'30':'GasHeaters',
'31':'ResidentialAC_ElectricBaseboard',
'32':'ResidentialAC_BoilerBaseboard',
'33':'ResidentialAC_ASHPBaseboard',
'34':'ResidentialAC_DHWBaseboard',
'35':'ResidentialAC_ResidentialFurnace',
'36':'ResidentialAC',
'37':'ResidentialHP',
'38':'ResidentialHPNoCool',
'39':'ResidentialFurnace',
'40':'VRF',
'41':'WSHP_FluidCooler_Boiler',
'42':'WSHP_CoolingTower_Boiler',
'43':'WSHP_GSHP',
'44':'WSHP_DCW_DHW',
'45':'WindowAC_ElectricBaseboard',
'46':'WindowAC_BoilerBaseboard',
'47':'WindowAC_ASHPBaseboard',
'48':'WindowAC_DHWBaseboard',
'49':'WindowAC_Furnace',
'50':'WindowAC_GasHeaters',
'51':'WindowAC',
'52':'VAV_Chiller_Boiler',
'53':'VAV_Chiller_ASHP',
'54':'VAV_Chiller_DHW',
'55':'VAV_Chiller_PFP',
'56':'VAV_Chiller_GasCoil',
'57':'VAV_ACChiller_Boiler',
'58':'VAV_ACChiller_ASHP',
'59':'VAV_ACChiller_DHW',
'60':'VAV_ACChiller_PFP',
'61':'VAV_ACChiller_GasCoil',
'62':'VAV_DCW_Boiler',
'63':'VAV_DCW_ASHP',
'64':'VAV_DCW_DHW',
'65':'VAV_DCW_PFP',
'66':'VAV_DCW_GasCoil',
'67':'PVAV_Boiler',
'68':'PVAV_ASHP',
'69':'PVAV_DHW',
'70':'PVAV_PFP',
'71':'PVAV_BoilerElectricReheat',
'72':'PSZAC_ElectricBaseboard',
'73':'PSZAC_BoilerBaseboard',
'74':'PSZAC_DHWBaseboard',
'75':'PSZAC_GasHeaters',
'76':'PSZAC_ElectricCoil',
'77':'PSZAC_GasCoil',
'78':'PSZAC_Boiler',
'79':'PSZAC_ASHP',
'80':'PSZAC_DHW',
'81':'PSZAC',
'82':'PSZAC_DCW_ElectricBaseboard',
'83':'PSZAC_DCW_BoilerBaseboard',
'84':'PSZAC_DCW_GasHeaters',
'85':'PSZAC_DCW_ElectricCoil',
'86':'PSZAC_DCW_GasCoil',
'87':'PSZAC_DCW_Boiler',
'88':'PSZAC_DCW_ASHP',
'89':'PSZAC_DCW_DHW',
'90':'PSZAC_DCW',
'91':'PSZHP',
'92':'PTAC_ElectricBaseboard',
'93':'PTAC_BoilerBaseboard',
'94':'PTAC_DHWBaseboard',
'95':'PTAC_GasHeaters',
'96':'PTAC_ElectricCoil',
'97':'PTAC_GasCoil',
'98':'PTAC_Boiler',
'99':'PTAC_ASHP',
'100':'PTAC_DHW',
'101':'PTAC',
'102':'PTHP',
'103':'Furnace',
'104':'DOAS_FCU_Chiller_Boiler',
'105':'DOAS_FCU_Chiller_ASHP',
'106':'DOAS_FCU_Chiller_DHW',
'107':'DOAS_FCU_Chiller_ElectricBaseboard',
'108':'DOAS_FCU_Chiller_GasHeaters',
'109':'DOAS_FCU_Chiller',
'110':'DOAS_FCU_ACChiller_Boiler',
'111':'DOAS_FCU_ACChiller_ASHP',
'112':'DOAS_FCU_ACChiller_DHW',
'113':'DOAS_FCU_ACChiller_ElectricBaseboard',
'114':'DOAS_FCU_ACChiller_GasHeaters',
'115':'DOAS_FCU_ACChiller',
'116':'DOAS_FCU_DCW_Boiler',
'117':'DOAS_FCU_DCW_ASHP',
'118':'DOAS_FCU_DCW_DHW',
'119':'DOAS_FCU_DCW_ElectricBaseboard',
'120':'DOAS_FCU_DCW_GasHeaters',
'121':'DOAS_FCU_DCW',
'122':'DOAS_VRF',
'123':'DOAS_WSHP_FluidCooler_Boiler',
'124':'DOAS_WSHP_CoolingTower_Boiler',
'125':'DOAS_WSHP_GSHP',
'126':'DOAS_WSHP_DCW_DHW',
}

# %%
data_in=read_write.read_variables_csv('Parameters.csv')
designSpaceMatrix = build.space_filling_lhs(data_in,num_samples = 20)
designSpaceMatrix = designSpaceMatrix.round(2)

integerColumnNames = ['Orientation','NumberOfFloors', 'Arm-Latitudinal-NumberOfSegments',
'Arm-Longitudinal-NumberOfSegments','BaseBody-Inside-Latditudinal-NumberOfSegments']
boolIntegerColumnNames = ['Has_Courtyard-Roof']
textColumnNames = ['Terrain','Fassade','EnergyStandard','Shading','HVAC-System_Template','Output-Directory',]

roundDict = {}
for nonNumberColumnName in integerColumnNames + boolIntegerColumnNames + textColumnNames:
    roundDict[nonNumberColumnName]=0
designSpaceMatrix = designSpaceMatrix.round(roundDict)

for integerColumnName in integerColumnNames:
    designSpaceMatrix[integerColumnName]=designSpaceMatrix[integerColumnName].astype('int')

for boolIntegerColumnName in boolIntegerColumnNames:
    designSpaceMatrix[boolIntegerColumnName]=designSpaceMatrix[boolIntegerColumnName].astype('bool')

for textColumnName in textColumnNames:
    designSpaceMatrix[textColumnName]=designSpaceMatrix[textColumnName].astype('int')
    designSpaceMatrix[textColumnName]=designSpaceMatrix[textColumnName].astype('str')

designSpaceMatrix['Terrain'] = designSpaceMatrix['Terrain'].map(terrain)
designSpaceMatrix['Fassade'] = designSpaceMatrix['Fassade'].map(fassade)
designSpaceMatrix['Shading'] = designSpaceMatrix['Shading'].map(shading)
designSpaceMatrix['EnergyStandard'] = designSpaceMatrix['EnergyStandard'].map(energyStandard)
designSpaceMatrix['HVAC-System_Template'] = designSpaceMatrix['HVAC-System_Template'].map(hvacSystemTemplates)
designSpaceMatrix['Output-Directory'] = designSpaceMatrix['Output-Directory'].map({'0':r'C:\Git\Work\FOR2363\Model-Runner\src'})

designSpaceMatrix.to_csv('DesignSpaceMatrix.csv')
print(designSpaceMatrix.dtypes)
designSpaceMatrix
# Out:
# Terrain                                           object
# Orientation                                        int32
# NumberOfFloors                                     int32
# FloorHeight                                      float64
# Fassade                                           object
# RasterLength-X                                   float64
# RasterLength-Y                                   float64
# Arm-Latitudinal-NumberOfSegments                   int32
# Arm-Longitudinal-NumberOfSegments                  int32
# BaseBody-Inside-Latditudinal-NumberOfSegments      int32
# Courtyard_SegmentCount_RasterLength-Y            float64
# Has_Courtyard-Roof                                  bool
# Shading                                           object
# EnergyStandard                                    object
# HVAC-System_Template                              object
# Output-Directory                                  object
# dtype: object
#     Terrain  Orientation  NumberOfFloors  FloorHeight             Fassade  \
# 0      City           76               9         4.32  Horizontal-Windows
# 1      City          133               1         4.23  Horizontal-Windows
# 2     Urban           19               6         4.14  Horizontal-Windows
# 3     Urban          180               9         4.05      Ribbon-Windows
# 4   Suburbs           47               4         2.80      Ribbon-Windows
# 5     Urban          152               2         3.52    Vertical-Windows
# 6      City           95               1         3.69    Vertical-Windows
# 7   Suburbs           28              10         3.87  Horizontal-Windows
# 8     Urban           66              10         3.16    Vertical-Windows
# 9     Urban          161               2         3.43    Vertical-Windows
# 10  Country           57               3         3.61    Vertical-Windows
# 11  Suburbs           85               5         3.96  Horizontal-Windows
# 12  Suburbs           38               3         4.41      Ribbon-Windows
# 13     City          171               5         3.25    Vertical-Windows
# 14    Urban            9               6         3.34    Vertical-Windows
# 15  Country          142               4         2.98      Ribbon-Windows
# 16  Country          114               8         2.89    Vertical-Windows
# 17  Suburbs          123               7         3.07    Vertical-Windows
# 18  Suburbs          104               7         4.50      Ribbon-Windows
# 19  Country            0               8         3.78    Vertical-Windows
#
#     RasterLength-X  RasterLength-Y  Arm-Latitudinal-NumberOfSegments  \
# 0             3.58            2.21                                 3
# 1             2.42            3.16                                 3
# 2             2.84            2.32                                 4
# 3             4.00            3.37                                 5
# 4             3.05            3.58                                 5
# 5             3.89            2.63                                 4
# 6             3.16            2.95                                 4
# 7             3.79            3.47                                 3
# 8             2.74            3.05                                 4
# 9             3.47            2.53                                 4
# 10            2.53            3.79                                 4
# 11            2.32            2.42                                 5
# 12            2.21            2.74                                 3
# 13            2.00            2.00                                 4
# 14            2.95            3.68                                 4
# 15            2.63            4.00                                 3
# 16            3.26            2.11                                 5
# 17            2.11            2.84                                 5
# 18            3.68            3.89                                 4
# 19            3.37            3.26                                 4
#
#     Arm-Longitudinal-NumberOfSegments  \
# 0                                   4
# 1                                   4
# 2                                   5
# 3                                   3
# 4                                   4
# 5                                   3
# 6                                   5
# 7                                   5
# 8                                   3
# 9                                   5
# 10                                  3
# 11                                  5
# 12                                  4
# 13                                  3
# 14                                  4
# 15                                  4
# 16                                  4
# 17                                  4
# 18                                  4
# 19                                  4
#
#     BaseBody-Inside-Latditudinal-NumberOfSegments  \
# 0                                               4
# 1                                               4
# 2                                               3
# 3                                               2
# 4                                               3
# 5                                               4
# 6                                               2
# 7                                               3
# 8                                               4
# 9                                               3
# 10                                              2
# 11                                              2
# 12                                              3
# 13                                              2
# 14                                              3
# 15                                              3
# 16                                              3
# 17                                              4
# 18                                              3
# 19                                              3
#
#     Courtyard_SegmentCount_RasterLength-Y  Has_Courtyard-Roof  \
# 0                                    8.58                True
# 1                                   12.37               False
# 2                                   11.11               False
# 3                                   13.00                True
# 4                                   10.79                True
# 5                                   10.16                True
# 6                                    9.53               False
# 7                                    8.26                True
# 8                                    9.84               False
# 9                                   12.68                True
# 10                                  10.47               False
# 11                                   7.00               False
# 12                                  12.05               False
# 13                                  11.74               False
# 14                                   8.89                True
# 15                                   9.21                True
# 16                                   7.95               False
# 17                                   7.32                True
# 18                                  11.42                True
# 19                                   7.63               False
#
#              Shading EnergyStandard HVAC-System_Template  \
# 0   External-Shading           NZEB        ASHPBaseboard
# 1     Low-SHGC-Value            GEG         DHWBaseboard
# 2   External-Shading            GEG        ASHPBaseboard
# 3   External-Shading            GEG        ASHPBaseboard
# 4   External-Shading           NZEB      BoilerBaseboard
# 5   External-Shading        Passive        ASHPBaseboard
# 6   External-Shading        Passive      BoilerBaseboard
# 7     Low-SHGC-Value            GEG        ASHPBaseboard
# 8     Low-SHGC-Value        Passive        ASHPBaseboard
# 9     Low-SHGC-Value           NZEB         DHWBaseboard
# 10    Low-SHGC-Value           NZEB      BoilerBaseboard
# 11    Low-SHGC-Value           NZEB         DHWBaseboard
# 12  External-Shading            GEG         DHWBaseboard
# 13  External-Shading        Passive        ASHPBaseboard
# 14    Low-SHGC-Value           NZEB        ASHPBaseboard
# 15    Low-SHGC-Value        Passive         DHWBaseboard
# 16    Low-SHGC-Value           NZEB      BoilerBaseboard
# 17  External-Shading           NZEB        ASHPBaseboard
# 18  External-Shading           NZEB        ASHPBaseboard
# 19    Low-SHGC-Value           NZEB      BoilerBaseboard
#
#                         Output-Directory
# 0   C:\Git\Work\FOR2363\Model-Runner\src
# 1   C:\Git\Work\FOR2363\Model-Runner\src
# 2   C:\Git\Work\FOR2363\Model-Runner\src
# 3   C:\Git\Work\FOR2363\Model-Runner\src
# 4   C:\Git\Work\FOR2363\Model-Runner\src
# 5   C:\Git\Work\FOR2363\Model-Runner\src
# 6   C:\Git\Work\FOR2363\Model-Runner\src
# 7   C:\Git\Work\FOR2363\Model-Runner\src
# 8   C:\Git\Work\FOR2363\Model-Runner\src
# 9   C:\Git\Work\FOR2363\Model-Runner\src
# 10  C:\Git\Work\FOR2363\Model-Runner\src
# 11  C:\Git\Work\FOR2363\Model-Runner\src
# 12  C:\Git\Work\FOR2363\Model-Runner\src
# 13  C:\Git\Work\FOR2363\Model-Runner\src
# 14  C:\Git\Work\FOR2363\Model-Runner\src
# 15  C:\Git\Work\FOR2363\Model-Runner\src
# 16  C:\Git\Work\FOR2363\Model-Runner\src
# 17  C:\Git\Work\FOR2363\Model-Runner\src
# 18  C:\Git\Work\FOR2363\Model-Runner\src
# 19  C:\Git\Work\FOR2363\Model-Runner\src

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Definitions

# %%
import compute_rhino3d
import compute_rhino3d.Grasshopper as gh
from rhino3dm import GeometryBase,File3dm,CommonObject,ObjectAttributes,Point3d
import json
from numpy import float64, int32, bool_

# %%
compute_rhino3d.Util.authToken = ""
compute_rhino3d.Util.url = "http://localhost:6500/"

# %%
def callGrasshopper(path,parameters):
    trees = convertToTrees(parameters)
    return gh.EvaluateDefinition(path, trees)

def convertToTrees(parameters):
    trees = []
    if type(parameters) is not dict:
        return "Parameters have to be a dictionary"
    for kw in parameters:
        branches = parameters[kw]
        tree = gh.DataTree(kw)
        #check if branches is just item
        if type(branches) != list:
            tree.Append([0], [encode(branches)])
        else:
            #check if branches is list
            if type(branches[0]) != list:
                tree.Append([0], [encode(item) for item in branches])
            else:
                for i,branch in enumerate(branches):
                    tree.Append([i], [encode(item) for item in branch])
        trees.append(tree)
    return trees

def encode(value):
    if type(value).__module__.startswith('rhino3dm'):
        return json.dumps(value.Encode())
    else:
        return value
    
def saveResults(values):
    #Save results
    model = File3dm()
    for val in values:
        paramName = val['ParamName']
        innerTree = val['InnerTree']
        isLayerInitialized=False
        for key, innerVals in innerTree.items():
            for innerVal in innerVals:
                #if innerVal['type'] != "System.String":
                try:
                    if not isLayerInitialized:
                        layerIndex = model.Layers.AddLayer(paramName,(0,0,0,255))
                        isLayerInitialized=True
                    data = json.loads(innerVal['data'])
                    decodedData = CommonObject.Decode(data)
                    objectAttributes = ObjectAttributes()
                    objectAttributes.LayerIndex = layerIndex
                    model.Objects.Add(decodedData,objectAttributes)
                except:
                    pass
    #model.Write(simulationResultsDirectory + '\\model.3dm')

# %% [markdown]
# ### Call

# %%
scriptPath = r"C:\Git\Work\FOR2363\Parametric-H-Shape-Office-Building-Model\src\Director.ghx"
parameters = designSpaceMatrix.iloc[1].to_dict()
# Find names here https://bigladdersoftware.com/epx/docs/22-2/input-output-reference/index.html
#parameters['Output-Names']=["Heating Coil Heating Rate","Heating Coil Electricity Rate"]
# See https://bigladdersoftware.com/epx/docs/22-2/input-output-reference/output-table-summaryreports.html#outputtablesummaryreports
# For some reason the summaries with empty spaces in the name do not work accordingly.
# If you need them just use AllSummaryMonthlyAndSizingPeriod to include everything
parameters['Report-Names']=["AllSummaryMonthlyAndSizingPeriod"]
parameters['HVAC-System_Template']="WindowAC_BoilerBaseboard"
parameters['SimulationMode']="1"
parameters
# Out:
# {'Terrain': 'City',
#  'Orientation': 133,
#  'NumberOfFloors': 1,
#  'FloorHeight': 4.23,
#  'Fassade': 'Horizontal-Windows',
#  'RasterLength-X': 2.42,
#  'RasterLength-Y': 3.16,
#  'Arm-Latitudinal-NumberOfSegments': 3,
#  'Arm-Longitudinal-NumberOfSegments': 4,
#  'BaseBody-Inside-Latditudinal-NumberOfSegments': 4,
#  'Courtyard_SegmentCount_RasterLength-Y': 12.37,
#  'Has_Courtyard-Roof': False,
#  'Shading': 'Low-SHGC-Value',
#  'EnergyStandard': 'GEG',
#  'HVAC-System_Template': 'WindowAC_BoilerBaseboard',
#  'Output-Directory': 'C:\\Git\\Work\\FOR2363\\Model-Runner\\src',
#  'Report-Names': ['AllSummaryMonthlyAndSizingPeriod'],
#  'SimulationMode': '1'}

# %%
result = callGrasshopper(scriptPath,parameters)
result
# Out:
# {'absolutetolerance': 0.0,
#  'angletolerance': 0.0,
#  'modelunits': 'Millimeters',
#  'algo': '',
#  'pointer': 'md5_DE52EA804E4672D808AFC35FA76B1C86',
#  'cachesolve': False,
#  'recursionlevel': 0,
#  'values': [{'ParamName': 'Zones',
#    'InnerTree': {'{0;0;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}]}},
#   {'ParamName': 'Windows',
#    'InnerTree': {'{0;1;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;6}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;7}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;6}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;7}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;6}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;6}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;5;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;6;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;7;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;1}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;2}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;3}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;4}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;8;5}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}]}},
#   {'ParamName': 'Zones_Underground',
#    'InnerTree': {'{0;0;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;1;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;2;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;3;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}],
#     '{0;4;0}': [{'type': 'Rhino.Geometry.Brep',
#       'data': '{"version":10000,"archive3dm":60,"opennurbs":-1906277639,"data":"..."}'}]}},
#   {'ParamName': 'Honeybee-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel.hbjson"'}]}},
#   {'ParamName': 'ZoneSizing-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\run\\\\\\\\epluszsz.csv"'}]}},
#   {'ParamName': 'SQL-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\run\\\\\\\\eplusout.sql"'}]}},
#   {'ParamName': 'ReportDataDictionary-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\run\\\\\\\\eplusout.rdd"'}]}},
#   {'ParamName': 'Reports-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\run\\\\\\\\eplustbl.htm"'}]}},
#   {'ParamName': 'IDF-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\run\\\\\\\\in.idf"'}]}},
#   {'ParamName': 'SimulationParameters-FilePath',
#    'InnerTree': {'{0;0;0}': [{'type': 'System.String',
#       'data': '"E:\\\\\\\\Nextcloud\\\\\\\\Public\\\\\\\\FOR2363\\\\\\\\TP4\\\\\\\\LUH\\\\\\\\HVAC-Systems\\\\\\\\BatchCurrent\\\\\\\\Data_Source\\\\\\\\Simulation-Files\\\\\\\\EnergyModel\\\\\\\\openstudio\\\\\\\\simulation_parameter.json"'}]}}],
#  'warnings': [],
#  'errors': []}

# %%
reportResult = callGrasshopper(r"C:\Git\Work\FOR2363\Parametric-H-Shape-Office-Building-Model\src\Reporting.ghx",{})
reportResult
# Out:
# {'absolutetolerance': 0.0,
#  'angletolerance': 0.0,
#  'modelunits': 'Millimeters',
#  'algo': '',
#  'pointer': 'md5_B6F02CB4B6AA97A374C5DD98794A6D43',
#  'cachesolve': False,
#  'recursionlevel': 0,
#  'values': [{'ParamName': 'eui',
#    'InnerTree': {'{0}': [{'type': 'System.String', 'data': '"79.203"'}]}},
#   {'ParamName': 'DHWDesignSizeNominalCapacity',
#    'InnerTree': {'{0;0}': [{'type': 'System.String',
#       'data': '"2073.522753"'}]}},
#   {'ParamName': 'AverageBaseboardDesignSizeU-FactorTimesArea',
#    'InnerTree': {'{0}': [{'type': 'System.String', 'data': '"0.000188"'}]}},
#   {'ParamName': 'EUI-Heating',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"34.488"'}]}},
#   {'ParamName': 'EUI-InteriorLighting',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"14.666"'}]}},
#   {'ParamName': 'EUI-InteriorEquipment',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"23.488"'}]}},
#   {'ParamName': 'EUI-Pumps',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"0.029"'}]}},
#   {'ParamName': 'EUI-Cooling',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"6.532"'}]}},
#   {'ParamName': 'GrossFloorArea',
#    'InnerTree': {'{0}': [{'type': 'System.String', 'data': '"3170.99"'}]}},
#   {'ParamName': 'HotWaterPumpDesignFlowRate',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"0.000099"'}]}},
#   {'ParamName': 'HotWaterPumpDesignPowerConsumption',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"4.206794"'}]}},
#   {'ParamName': 'AverageBaseboardsDesignSizeMaximumWaterFlowRate',
#    'InnerTree': {'{0}': [{'type': 'System.String', 'data': '"0.000188"'}]}},
#   {'ParamName': 'AnnualHeatEmissions-EnvelopeConvection',
#    'InnerTree': {'{0}': [{'type': 'System.String', 'data': '"0"'}]}},
#   {'ParamName': 'AnnualHeatEmissions-Total',
#    'InnerTree': {'{0;0}': [{'type': 'System.String',
#       'data': '"715036.111111"'}]}},
#   {'ParamName': 'AnnualHeatEmissionsZone-Exfiltration',
#    'InnerTree': {'{0;0}': [{'type': 'System.String',
#       'data': '"83908.333333"'}]}},
#   {'ParamName': 'AnnualHeatEmissionsZone-ZoneExhaustAir',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"0"'}]}},
#   {'ParamName': 'AnnualHeatEmissionsZone-HVACReliefAir',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"0"'}]}},
#   {'ParamName': 'AnnualHeatEmissionsZone-HVACRejectHeat',
#    'InnerTree': {'{0;0}': [{'type': 'System.String', 'data': '"81550"'}]}},
#   {'ParamName': 'BoilerDesignSizeNominalCapacity',
#    'InnerTree': {'{0;0}': [{'type': 'System.String',
#       'data': '"120521.567393"'}]}}],
#  'warnings': [],
#  'errors': []}

# %% [markdown]
# ## Post processing of results

# %% [markdown]
# ### Definitions

# %%
import csv
from os.path import exists,join,dirname,abspath

# %%
def parseSingleResults(valuesReply):
    results = {}
    log = []
    for valueReply in valuesReply['values']:
        tree = valueReply['InnerTree']
        if len(tree)!=1:
            log.append("Tree did not have exactly one 1 branch" +valueReply)
            continue
        value =list(tree.values())[0]
        if len(value)!=1:
            log.append("Branch did not have exactly one 1 value")
        results[valueReply['ParamName']]=value[0]['data'].strip('"')
    return (results,log)

def appendValuesToFile(filePath,fieldnames,values):
    # with open(filePath, ) as csvfile: 
    #     csvwriter = csv.writer(csvfile)
    #     csvwriter.write(values)
    #     csvwriter.writerow(values)
    if not exists(filePath):
        with open(filePath, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
    with open(filePath, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writerow(values)
# Out:
# {'Terrain': 'City',
#  'Orientation': 133,
#  'NumberOfFloors': 1,
#  'FloorHeight': 4.23,
#  'Fassade': 'Horizontal-Windows',
#  'RasterLength-X': 2.42,
#  'RasterLength-Y': 3.16,
#  'Arm-Latitudinal-NumberOfSegments': 3,
#  'Arm-Longitudinal-NumberOfSegments': 4,
#  'BaseBody-Inside-Latditudinal-NumberOfSegments': 4,
#  'Courtyard_SegmentCount_RasterLength-Y': 12.37,
#  'Has_Courtyard-Roof': False,
#  'Shading': 'Low-SHGC-Value',
#  'EnergyStandard': 'GEG',
#  'HVAC-System_Template': 'WindowAC_BoilerBaseboard',
#  'Output-Directory': 'C:\\Git\\Work\\FOR2363\\Model-Runner\\src',
#  'Report-Names': ['AllSummaryMonthlyAndSizingPeriod'],
#  'SimulationMode': '1',
#  'eui': '79.203',
#  'DHWDesignSizeNominalCapacity': '2073.522753',
#  'AverageBaseboardDesignSizeU-FactorTimesArea': '0.000188',
#  'EUI-Heating': '34.488',
#  'EUI-InteriorLighting': '14.666',
#  'EUI-InteriorEquipment': '23.488',
#  'EUI-Pumps': '0.029',
#  'EUI-Cooling': '6.532',
#  'GrossFloorArea': '3170.99',
#  'HotWaterPumpDesignFlowRate': '0.000099',
#  'HotWaterPumpDesignPowerConsumption': '4.206794',
#  'AverageBaseboardsDesignSizeMaximumWaterFlowRate': '0.000188',
#  'AnnualHeatEmissions-EnvelopeConvection': '0',
#  'AnnualHeatEmissions-Total': '715036.111111',
#  'AnnualHeatEmissionsZone-Exfiltration': '83908.333333',
#  'AnnualHeatEmissionsZone-ZoneExhaustAir': '0',
#  'AnnualHeatEmissionsZone-HVACReliefAir': '0',
#  'AnnualHeatEmissionsZone-HVACRejectHeat': '81550',
#  'BoilerDesignSizeNominalCapacity': '120521.567393'}

# %% [markdown]
# ### Write

# %%
cleanResults,log = parseSingleResults(reportResult)
headers = ['Terrain',
 'Orientation',
 'NumberOfFloors',
 'FloorHeight',
 'Fassade',
 'RasterLength-X',
 'RasterLength-Y',
 'Arm-Latitudinal-NumberOfSegments',
 'Arm-Longitudinal-NumberOfSegments',
 'BaseBody-Inside-Latditudinal-NumberOfSegments',
 'Courtyard_SegmentCount_RasterLength-Y',
 'Has_Courtyard-Roof',
 'Shading',
 'EnergyStandard',
 'HVAC-System_Template',
 'Output-Directory',
 'Report-Names',
 'SimulationMode'] + ['eui',
 'DHWDesignSizeNominalCapacity',
 'AverageBaseboardDesignSizeU-FactorTimesArea',
 'EUI-Heating',
 'EUI-InteriorLighting',
 'EUI-InteriorEquipment',
 'EUI-Pumps',
 'EUI-Cooling',
 'GrossFloorArea',
 'HotWaterPumpDesignFlowRate',
 'HotWaterPumpDesignPowerConsumption',
 'AverageBaseboardsDesignSizeMaximumWaterFlowRate',
 'AnnualHeatEmissions-EnvelopeConvection',
 'AnnualHeatEmissions-Total',
 'AnnualHeatEmissionsZone-Exfiltration',
 'AnnualHeatEmissionsZone-ZoneExhaustAir',
 'AnnualHeatEmissionsZone-HVACReliefAir',
 'AnnualHeatEmissionsZone-HVACRejectHeat',
 'BoilerDesignSizeNominalCapacity']
values = {**parameters,**cleanResults}
appendValuesToFile("results.csv",headers,values)
values
# Out:
# {'Terrain': 'City',
#  'Orientation': 133,
#  'NumberOfFloors': 1,
#  'FloorHeight': 4.23,
#  'Fassade': 'Horizontal-Windows',
#  'RasterLength-X': 2.42,
#  'RasterLength-Y': 3.16,
#  'Arm-Latitudinal-NumberOfSegments': 3,
#  'Arm-Longitudinal-NumberOfSegments': 4,
#  'BaseBody-Inside-Latditudinal-NumberOfSegments': 4,
#  'Courtyard_SegmentCount_RasterLength-Y': 12.37,
#  'Has_Courtyard-Roof': False,
#  'Shading': 'Low-SHGC-Value',
#  'EnergyStandard': 'GEG',
#  'HVAC-System_Template': 'WindowAC_BoilerBaseboard',
#  'Output-Directory': 'C:\\Git\\Work\\FOR2363\\Model-Runner\\src',
#  'Report-Names': ['AllSummaryMonthlyAndSizingPeriod'],
#  'SimulationMode': '1',
#  'eui': '79.203',
#  'DHWDesignSizeNominalCapacity': '2073.522753',
#  'AverageBaseboardDesignSizeU-FactorTimesArea': '0.000188',
#  'EUI-Heating': '34.488',
#  'EUI-InteriorLighting': '14.666',
#  'EUI-InteriorEquipment': '23.488',
#  'EUI-Pumps': '0.029',
#  'EUI-Cooling': '6.532',
#  'GrossFloorArea': '3170.99',
#  'HotWaterPumpDesignFlowRate': '0.000099',
#  'HotWaterPumpDesignPowerConsumption': '4.206794',
#  'AverageBaseboardsDesignSizeMaximumWaterFlowRate': '0.000188',
#  'AnnualHeatEmissions-EnvelopeConvection': '0',
#  'AnnualHeatEmissions-Total': '715036.111111',
#  'AnnualHeatEmissionsZone-Exfiltration': '83908.333333',
#  'AnnualHeatEmissionsZone-ZoneExhaustAir': '0',
#  'AnnualHeatEmissionsZone-HVACReliefAir': '0',
#  'AnnualHeatEmissionsZone-HVACRejectHeat': '81550',
#  'BoilerDesignSizeNominalCapacity': '120521.567393'}

# %% [markdown]
# ## Batch
