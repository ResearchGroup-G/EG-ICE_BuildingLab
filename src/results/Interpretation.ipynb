# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
from sklearn.metrics import mean_squared_error,precision_score, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as stats
from csv import writer

# %%
figureSize = (20,15)

# %%
df = pd.read_csv("Results.csv")
decription = df.describe().transpose().drop(columns={"count","25%","50%","75%"})
decription.to_csv('Description.csv')

# %%
#sns.pairplot(df)
plt.subplots(figsize=figureSize)
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#sns.pairplot(df,vars = ['Heating','Cooling','U-Value_Panels','U-Value_Sandwich','U-Value_Skylight','U-Value_Wall-Exterior','U-Value_Roof','SHGC_Panels','SHGC_Sandwich','SHGC_Skylight',])

# %%
splits = list(df.groupby("HVAC-System"))
df_ashp = splits[0][1]
df_boiler = splits[1][1]
df_dhw = splits[2][1]

# %% [markdown]
# ## ASHP

# %%
decriptionASHP = df_ashp.describe().transpose().drop(columns={"count","25%","50%","75%"})
decriptionASHP.to_csv('ASHP_Description.csv')

# %%
fig, ax= plt.subplots(figsize=figureSize)
sns.heatmap(df_ashp.corr())
fig.savefig('ASHP_Pairplot.png')

# %% [markdown]
# ## Boiler

# %%
decriptionBoiler = df_boiler.describe().transpose().drop(columns={"count","25%","50%","75%"})
decriptionBoiler.to_csv('Boiler_Description.csv')

# %%
fig, ax= plt.subplots(figsize=figureSize)
sns.heatmap(df_boiler.corr())
fig.savefig('ASHP_Boiler.png')

# %% [markdown]
# ## DHW

# %%
decriptionDHW = df_dhw.describe().transpose().drop(columns={"count","25%","50%","75%"})
decriptionDHWE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Systems\CurrentBatchE:\Nextcloud\Public\FOR2363\TP4\LUH\HVAC-Syste.to_csv('DHW_Description.csv')

# %%
fig, ax= plt.subplots(figsize=figureSize)
sns.heatmap(df_dhw.corr())
fig.savefig('DHW_Boiler.png')
